# %%
# !pip install requests beautifulsoup4 pandas

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

# %%
url = "https://news.ycombinator.com"

response = requests.get(url)

response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
titles = soup.select(".titleline a")

len(titles)
# Out:
# 60

# %%
articles = []

for title in titles[:10]:
  articles.append({
      "title": title.text,
      "link": title["href"]
  })

articles
# Out:
# [{'title': 'Heathrow scraps liquid container limit',
#   'link': 'https://www.bbc.com/news/articles/c1evvx89559o'},
#  {'title': 'bbc.com', 'link': 'from?site=bbc.com'},
#  {'title': 'Kimi Released Kimi K2.5, Open-Source Visual SOTA-Agentic Model',
#   'link': 'https://www.kimi.com/blog/kimi-k2-5.html'},
#  {'title': 'kimi.com', 'link': 'from?site=kimi.com'},
#  {'title': 'A list of fun destinations for telnet',
#   'link': 'https://telnet.org/htm/places.htm'},
#  {'title': 'telnet.org', 'link': 'from?site=telnet.org'},
#  {'title': 'The Universal Pattern Popping Up in Math, Physics and Biology',
#   'link': 'https://www.quantamagazine.org/in-mysterious-pattern-math-and-nature-converge-20130205/'},
#  {'title': 'quantamagazine.org', 'link': 'from?site=quantamagazine.org'},
#  {'title': 'The hidden engineering of runways',
#   'link': 'https://practical.engineering/blog/2026/1/20/the-hidden-engineering-of-runways'},
# ...

# %%
df = pd.DataFrame(articles)
df
# Out:
#                                                title  \
# 0             Heathrow scraps liquid container limit
# 1                                            bbc.com
# 2  Kimi Released Kimi K2.5, Open-Source Visual SO...
# 3                                           kimi.com
# 4              A list of fun destinations for telnet
# 5                                         telnet.org
# 6  The Universal Pattern Popping Up in Math, Phys...
# 7                                 quantamagazine.org
# 8                  The hidden engineering of runways
# 9                              practical.engineering
#
#                                                 link
# 0     https://www.bbc.com/news/articles/c1evvx89559o
# 1                                  from?site=bbc.com
# 2           https://www.kimi.com/blog/kimi-k2-5.html
# 3                                 from?site=kimi.com
# 4                  https://telnet.org/htm/places.htm
# 5                               from?site=telnet.org
# ...

# %%
df.to_csv("articles.csv", index=False)

# %%
with open("articles.json", "w", encoding="utf-8")as f:
  json.dump(articles, f, ensure_ascii=False, indent=4)

# %%
# !ls
# Out:
# articles.csv  articles.json  final_articles.csv  final_data.json  sample_data

# %%
API_KEY = "2dec56099736763385358fc59f02dd3b"
CITY = "Tirana"

# %%
weather_url = (
    f"https://api.openweathermap.org/data/2.5/weather"
    f"?q={CITY}&appid={API_KEY}&units=metric"
)

weather_response = requests.get(weather_url)
weather_response.status_code
# Out:
# 200

# %%
weather_data = weather_response.json()
weather_data
# Out:
# {'coord': {'lon': 19.8189, 'lat': 41.3275},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 12.49,
#   'feels_like': 11.54,
#   'temp_min': 12.49,
#   'temp_max': 12.49,
#   'pressure': 1005,
#   'humidity': 67,
#   'sea_level': 1005,
#   'grnd_level': 968},
#  'visibility': 10000,
#  'wind': {'speed': 2.06, 'deg': 340},
#  'clouds': {'all': 20},
#  'dt': 1769511193,
#  'sys': {'type': 1,
#   'id': 6359,
#   'country': 'AL',
#   'sunrise': 1769493411,
#   'sunset': 1769528986},
#  'timezone': 3600,
#  'id': 3183875,
#  'name': 'Tirana',
#  'cod': 200}

# %%
weather_info = {
    "city":CITY,
    "temperature_celsius": weather_data["main"]["temp"],
    "weather_description": weather_data["weather"][0]["description"]
}

weather_info
# Out:
# {'city': 'Tirana',
#  'temperature_celsius': 12.49,
#  'weather_description': 'few clouds'}

# %%
final_data = {
    "articles": articles,
    "weather": weather_info
}

final_data
# Out:
# {'articles': [{'title': 'Heathrow scraps liquid container limit',
#    'link': 'https://www.bbc.com/news/articles/c1evvx89559o'},
#   {'title': 'bbc.com', 'link': 'from?site=bbc.com'},
#   {'title': 'Kimi Released Kimi K2.5, Open-Source Visual SOTA-Agentic Model',
#    'link': 'https://www.kimi.com/blog/kimi-k2-5.html'},
#   {'title': 'kimi.com', 'link': 'from?site=kimi.com'},
#   {'title': 'A list of fun destinations for telnet',
#    'link': 'https://telnet.org/htm/places.htm'},
#   {'title': 'telnet.org', 'link': 'from?site=telnet.org'},
#   {'title': 'The Universal Pattern Popping Up in Math, Physics and Biology',
#    'link': 'https://www.quantamagazine.org/in-mysterious-pattern-math-and-nature-converge-20130205/'},
#   {'title': 'quantamagazine.org', 'link': 'from?site=quantamagazine.org'},
#   {'title': 'The hidden engineering of runways',
#    'link': 'https://practical.engineering/blog/2026/1/20/the-hidden-engineering-of-runways'},
#   {'title': 'practical.engineering',
# ...

# %%
with open("final_data.json", "w", encoding="utf-8") as f:
  json.dump(final_data, f, ensure_ascii=False, indent=4)

# %%
df_articles = pd.DataFrame(final_data["articles"])
df_articles.to_csv("final_articles.csv", index=False)

# %%
# !ls
# Out:
# articles.csv  articles.json  final_articles.csv  final_data.json  sample_data

# %%
import json

with open("final_data.json", "r", encoding="utf-8") as f:
  final_data = json.load(f)

final_data
# Out:
# {'articles': [{'title': 'Heathrow scraps liquid container limit',
#    'link': 'https://www.bbc.com/news/articles/c1evvx89559o'},
#   {'title': 'bbc.com', 'link': 'from?site=bbc.com'},
#   {'title': 'Kimi Released Kimi K2.5, Open-Source Visual SOTA-Agentic Model',
#    'link': 'https://www.kimi.com/blog/kimi-k2-5.html'},
#   {'title': 'kimi.com', 'link': 'from?site=kimi.com'},
#   {'title': 'A list of fun destinations for telnet',
#    'link': 'https://telnet.org/htm/places.htm'},
#   {'title': 'telnet.org', 'link': 'from?site=telnet.org'},
#   {'title': 'The Universal Pattern Popping Up in Math, Physics and Biology',
#    'link': 'https://www.quantamagazine.org/in-mysterious-pattern-math-and-nature-converge-20130205/'},
#   {'title': 'quantamagazine.org', 'link': 'from?site=quantamagazine.org'},
#   {'title': 'The hidden engineering of runways',
#    'link': 'https://practical.engineering/blog/2026/1/20/the-hidden-engineering-of-runways'},
#   {'title': 'practical.engineering',
# ...

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/.git/

# %%
# !git config --global user.name "Kristi Madolli"
# !git config --global user.email "kristi_madolli@universitetipolis.edu.al"

# %%
# !git add scraper.ipynb data.csv data.json final_data.json
# Out:
# fatal: pathspec 'scraper.ipynb' did not match any files

# %%
# !ls
# Out:
# articles.csv  articles.json  final_articles.csv  final_data.json  sample_data

# %%
# !pwd
# Out:
# /content

# %%
# !ls -la
# Out:
# total 36
# drwxr-xr-x 1 root root 4096 Jan 27 10:26 .
# drwxr-xr-x 1 root root 4096 Jan 27 10:26 ..
# -rw-r--r-- 1 root root  728 Jan 27 10:57 articles.csv
# -rw-r--r-- 1 root root 1225 Jan 27 10:57 articles.json
# drwxr-xr-x 4 root root 4096 Jan 16 14:24 .config
# -rw-r--r-- 1 root root  728 Jan 27 10:57 final_articles.csv
# -rw-r--r-- 1 root root 1541 Jan 27 10:57 final_data.json
# drwxr-xr-x 7 root root 4096 Jan 27 10:57 .git
# drwxr-xr-x 1 root root 4096 Jan 16 14:24 sample_data
